# %%
#### Début du programme

data = [23, 5, 43, -5, 4, 2, 9, -13]

# %%
import math
import statistics

# %%
mean = statistics.mean(data)
mean
# Out:
# 8.5

# %%
ecart_type = statistics.stdev(data)
ecart_type
# Out:
# 17.40279123753264

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data)
